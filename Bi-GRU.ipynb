# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, Bidirectional, TimeDistributed
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error,mean_absolute_error
import math
import matplotlib.patches as mpatches
# Out:
# WARNING:tensorflow:From C:\Users\alek7andra13\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load the dataset from CSV
time_series_dataset = pd.read_csv('../outputs/mutation_timeseries3.csv', skiprows=1)

# Convert the dataset to float32
time_series_dataset = time_series_dataset.astype('float32')
print('Dataset Shape: ', time_series_dataset.shape)

# Apply Min-Max scaling
scaler = MinMaxScaler(feature_range=(0, 1))
dataset_scaled = scaler.fit_transform(time_series_dataset)

# Split dataset into train and test sets
train_size = int(len(dataset_scaled) * 0.90)
train, test = dataset_scaled[:train_size], dataset_scaled[train_size:]
print(len(train), len(test))
# Out:
# Dataset Shape:  (806, 12)
# 725 81

# %%
def create_dataset(time_series_dataset, look_back, batch_size):
    dataX, dataY = [], []
    for i in range(0, len(time_series_dataset) - look_back - 1, batch_size):
        a = time_series_dataset[i:(i + look_back)]
        dataX.append(a)
        dataY.append(time_series_dataset[i + look_back])
    return np.array(dataX), np.array(dataY)

batch_size = 1
look_back = 12
trainX, trainY = create_dataset(train, look_back, batch_size)
testX, testY = create_dataset(test, look_back, batch_size)
print(len(trainX), len(testX))
# Out:
# 712 68

# %%
# Build and Train Bidirectional GRU Network
model = Sequential()

# Input layer
model.add(Bidirectional(GRU(32, return_sequences=True, activation='tanh', recurrent_activation='sigmoid'), input_shape=(look_back, len(time_series_dataset.columns))))
model.add(Dropout(0.2))

# Bidirectional GRU layer
model.add(Bidirectional(GRU(32, return_sequences=True, activation='tanh', recurrent_activation='sigmoid')))
model.add(Dropout(0.2))

# TimeDistributed Dense layer
model.add(TimeDistributed(Dense(1, activation='linear')))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=["accuracy"])

# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, min_lr=0.001)

history = model.fit(trainX, trainY, epochs=100, batch_size=16, verbose=2, validation_data=(testX, testY), callbacks=[early_stop, reduce_lr])
# Out:
# WARNING:tensorflow:From C:\Users\alek7andra13\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\alek7andra13\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\alek7andra13\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\alek7andra13\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 45/45 - 10s - loss: 0.0397 - accuracy: 0.0016 - val_loss: 0.0030 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 10s/epoch - 228ms/step
# Epoch 2/100
# 45/45 - 1s - loss: 0.0196 - accuracy: 0.0014 - val_loss: 0.0039 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 588ms/epoch - 13ms/step
# Epoch 3/100
# 45/45 - 1s - loss: 0.0186 - accuracy: 0.0015 - val_loss: 0.0017 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 575ms/epoch - 13ms/step
# Epoch 4/100
# 45/45 - 1s - loss: 0.0164 - accuracy: 0.0015 - val_loss: 0.0015 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 590ms/epoch - 13ms/step
# Epoch 5/100
# 45/45 - 1s - loss: 0.0154 - accuracy: 0.0015 - val_loss: 0.0017 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 582ms/epoch - 13ms/step
# Epoch 6/100
# 45/45 - 1s - loss: 0.0146 - accuracy: 0.0015 - val_loss: 0.0017 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 584ms/epoch - 13ms/step
# Epoch 7/100
# 45/45 - 1s - loss: 0.0152 - accuracy: 0.0015 - val_loss: 0.0013 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 592ms/epoch - 13ms/step
# Epoch 8/100
# 45/45 - 1s - loss: 0.0139 - accuracy: 0.0015 - val_loss: 0.0022 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 583ms/epoch - 13ms/step
# Epoch 9/100
# 45/45 - 1s - loss: 0.0137 - accuracy: 0.0015 - val_loss: 0.0020 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 621ms/epoch - 14ms/step
# Epoch 10/100
# 45/45 - 1s - loss: 0.0133 - accuracy: 0.0015 - val_loss: 0.0020 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 574ms/epoch - 13ms/step
# Epoch 11/100
# 45/45 - 1s - loss: 0.0128 - accuracy: 0.0015 - val_loss: 0.0013 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 583ms/epoch - 13ms/step
# Epoch 12/100
# 45/45 - 1s - loss: 0.0129 - accuracy: 0.0015 - val_loss: 0.0013 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 593ms/epoch - 13ms/step
# Epoch 13/100
# 45/45 - 1s - loss: 0.0125 - accuracy: 0.0015 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 598ms/epoch - 13ms/step
# Epoch 14/100
# 45/45 - 1s - loss: 0.0121 - accuracy: 0.0015 - val_loss: 0.0014 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 644ms/epoch - 14ms/step
# Epoch 15/100
# 45/45 - 1s - loss: 0.0113 - accuracy: 0.0015 - val_loss: 0.0015 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 630ms/epoch - 14ms/step
# Epoch 16/100
# 45/45 - 1s - loss: 0.0112 - accuracy: 0.0015 - val_loss: 0.0014 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 629ms/epoch - 14ms/step
# Epoch 17/100
# 45/45 - 1s - loss: 0.0108 - accuracy: 0.0015 - val_loss: 0.0020 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 611ms/epoch - 14ms/step
# Epoch 18/100
# 45/45 - 1s - loss: 0.0117 - accuracy: 0.0015 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 631ms/epoch - 14ms/step
# Epoch 19/100
# 45/45 - 1s - loss: 0.0102 - accuracy: 0.0015 - val_loss: 0.0013 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 628ms/epoch - 14ms/step
# Epoch 20/100
# 45/45 - 1s - loss: 0.0098 - accuracy: 0.0015 - val_loss: 0.0023 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 633ms/epoch - 14ms/step
# Epoch 21/100
# 45/45 - 1s - loss: 0.0086 - accuracy: 0.0015 - val_loss: 0.0016 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 565ms/epoch - 13ms/step
# Epoch 22/100
# 45/45 - 1s - loss: 0.0088 - accuracy: 0.0015 - val_loss: 0.0014 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 589ms/epoch - 13ms/step
# Epoch 23/100
# 45/45 - 1s - loss: 0.0079 - accuracy: 0.0015 - val_loss: 0.0012 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 583ms/epoch - 13ms/step
# Epoch 24/100
# 45/45 - 1s - loss: 0.0085 - accuracy: 0.0015 - val_loss: 0.0012 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 565ms/epoch - 13ms/step
# Epoch 25/100
# 45/45 - 1s - loss: 0.0072 - accuracy: 0.0015 - val_loss: 0.0015 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 563ms/epoch - 13ms/step
# Epoch 26/100
# 45/45 - 1s - loss: 0.0072 - accuracy: 0.0015 - val_loss: 0.0019 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 562ms/epoch - 12ms/step
# Epoch 27/100
# 45/45 - 1s - loss: 0.0066 - accuracy: 0.0015 - val_loss: 0.0015 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 598ms/epoch - 13ms/step
# Epoch 28/100
# 45/45 - 1s - loss: 0.0068 - accuracy: 0.0015 - val_loss: 0.0013 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 642ms/epoch - 14ms/step
# Epoch 29/100
# 45/45 - 1s - loss: 0.0069 - accuracy: 0.0015 - val_loss: 0.0022 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 566ms/epoch - 13ms/step
# Epoch 30/100
# 45/45 - 1s - loss: 0.0063 - accuracy: 0.0015 - val_loss: 0.0014 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 562ms/epoch - 12ms/step
# Epoch 31/100
# 45/45 - 1s - loss: 0.0060 - accuracy: 0.0015 - val_loss: 0.0019 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 567ms/epoch - 13ms/step
# Epoch 32/100
# 45/45 - 1s - loss: 0.0061 - accuracy: 0.0015 - val_loss: 0.0015 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 560ms/epoch - 12ms/step
# Epoch 33/100
# 45/45 - 1s - loss: 0.0058 - accuracy: 0.0015 - val_loss: 0.0020 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 575ms/epoch - 13ms/step
# Epoch 34/100
# 45/45 - 1s - loss: 0.0057 - accuracy: 0.0015 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 632ms/epoch - 14ms/step
# Epoch 35/100
# 45/45 - 1s - loss: 0.0055 - accuracy: 0.0015 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 652ms/epoch - 14ms/step
# Epoch 36/100
# 45/45 - 1s - loss: 0.0057 - accuracy: 0.0015 - val_loss: 0.0023 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 575ms/epoch - 13ms/step
# Epoch 37/100
# 45/45 - 1s - loss: 0.0054 - accuracy: 0.0015 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 570ms/epoch - 13ms/step
# Epoch 38/100
# 45/45 - 1s - loss: 0.0051 - accuracy: 0.0015 - val_loss: 0.0014 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 575ms/epoch - 13ms/step
# Epoch 39/100
# 45/45 - 1s - loss: 0.0054 - accuracy: 0.0015 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 638ms/epoch - 14ms/step
# Epoch 40/100
# 45/45 - 1s - loss: 0.0051 - accuracy: 0.0015 - val_loss: 8.8349e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 607ms/epoch - 13ms/step
# Epoch 41/100
# 45/45 - 1s - loss: 0.0048 - accuracy: 0.0015 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 612ms/epoch - 14ms/step
# Epoch 42/100
# 45/45 - 1s - loss: 0.0047 - accuracy: 0.0015 - val_loss: 8.6350e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 639ms/epoch - 14ms/step
# Epoch 43/100
# 45/45 - 1s - loss: 0.0047 - accuracy: 0.0015 - val_loss: 0.0013 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 603ms/epoch - 13ms/step
# Epoch 44/100
# 45/45 - 1s - loss: 0.0046 - accuracy: 0.0015 - val_loss: 0.0022 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 611ms/epoch - 14ms/step
# Epoch 45/100
# 45/45 - 1s - loss: 0.0046 - accuracy: 0.0015 - val_loss: 9.6941e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 560ms/epoch - 12ms/step
# Epoch 46/100
# 45/45 - 1s - loss: 0.0043 - accuracy: 0.0015 - val_loss: 0.0024 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 594ms/epoch - 13ms/step
# Epoch 47/100
# 45/45 - 1s - loss: 0.0044 - accuracy: 0.0015 - val_loss: 9.6511e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 600ms/epoch - 13ms/step
# Epoch 48/100
# 45/45 - 1s - loss: 0.0042 - accuracy: 0.0015 - val_loss: 8.8209e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 598ms/epoch - 13ms/step
# Epoch 49/100
# 45/45 - 1s - loss: 0.0043 - accuracy: 0.0015 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 599ms/epoch - 13ms/step
# Epoch 50/100
# 45/45 - 1s - loss: 0.0044 - accuracy: 0.0015 - val_loss: 7.7048e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 613ms/epoch - 14ms/step
# Epoch 51/100
# 45/45 - 1s - loss: 0.0041 - accuracy: 0.0015 - val_loss: 0.0013 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 590ms/epoch - 13ms/step
# Epoch 52/100
# 45/45 - 1s - loss: 0.0040 - accuracy: 0.0015 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 604ms/epoch - 13ms/step
# Epoch 53/100
# 45/45 - 1s - loss: 0.0038 - accuracy: 0.0015 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 652ms/epoch - 14ms/step
# Epoch 54/100
# 45/45 - 1s - loss: 0.0039 - accuracy: 0.0015 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 599ms/epoch - 13ms/step
# Epoch 55/100
# 45/45 - 1s - loss: 0.0041 - accuracy: 0.0015 - val_loss: 9.2330e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 639ms/epoch - 14ms/step
# Epoch 56/100
# 45/45 - 1s - loss: 0.0039 - accuracy: 0.0015 - val_loss: 8.4732e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 673ms/epoch - 15ms/step
# Epoch 57/100
# 45/45 - 1s - loss: 0.0036 - accuracy: 0.0015 - val_loss: 7.8769e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 720ms/epoch - 16ms/step
# Epoch 58/100
# 45/45 - 1s - loss: 0.0036 - accuracy: 0.0015 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 598ms/epoch - 13ms/step
# Epoch 59/100
# 45/45 - 1s - loss: 0.0038 - accuracy: 0.0015 - val_loss: 8.9486e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 600ms/epoch - 13ms/step
# Epoch 60/100
# 45/45 - 1s - loss: 0.0035 - accuracy: 0.0015 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 598ms/epoch - 13ms/step
# Epoch 61/100
# 45/45 - 1s - loss: 0.0039 - accuracy: 0.0015 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 600ms/epoch - 13ms/step
# Epoch 62/100
# 45/45 - 1s - loss: 0.0035 - accuracy: 0.0015 - val_loss: 9.1677e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 602ms/epoch - 13ms/step
# Epoch 63/100
# 45/45 - 1s - loss: 0.0038 - accuracy: 0.0015 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 642ms/epoch - 14ms/step
# Epoch 64/100
# 45/45 - 1s - loss: 0.0037 - accuracy: 0.0015 - val_loss: 0.0020 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 687ms/epoch - 15ms/step
# Epoch 65/100
# 45/45 - 1s - loss: 0.0036 - accuracy: 0.0015 - val_loss: 8.7664e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 631ms/epoch - 14ms/step
# Epoch 66/100
# 45/45 - 1s - loss: 0.0032 - accuracy: 0.0015 - val_loss: 8.5223e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 614ms/epoch - 14ms/step
# Epoch 67/100
# 45/45 - 1s - loss: 0.0032 - accuracy: 0.0015 - val_loss: 9.0990e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 605ms/epoch - 13ms/step
# Epoch 68/100
# 45/45 - 1s - loss: 0.0034 - accuracy: 0.0015 - val_loss: 0.0011 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 669ms/epoch - 15ms/step
# Epoch 69/100
# 45/45 - 1s - loss: 0.0035 - accuracy: 0.0015 - val_loss: 7.5367e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 677ms/epoch - 15ms/step
# Epoch 70/100
# 45/45 - 1s - loss: 0.0032 - accuracy: 0.0015 - val_loss: 0.0017 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 685ms/epoch - 15ms/step
# Epoch 71/100
# 45/45 - 1s - loss: 0.0033 - accuracy: 0.0015 - val_loss: 9.0271e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 622ms/epoch - 14ms/step
# Epoch 72/100
# 45/45 - 1s - loss: 0.0033 - accuracy: 0.0015 - val_loss: 7.7434e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 560ms/epoch - 12ms/step
# Epoch 73/100
# 45/45 - 1s - loss: 0.0031 - accuracy: 0.0015 - val_loss: 8.7929e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 558ms/epoch - 12ms/step
# Epoch 74/100
# 45/45 - 1s - loss: 0.0031 - accuracy: 0.0015 - val_loss: 7.0835e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 561ms/epoch - 12ms/step
# Epoch 75/100
# 45/45 - 1s - loss: 0.0032 - accuracy: 0.0015 - val_loss: 0.0012 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 569ms/epoch - 13ms/step
# Epoch 76/100
# 45/45 - 1s - loss: 0.0032 - accuracy: 0.0015 - val_loss: 9.2919e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 533ms/epoch - 12ms/step
# Epoch 77/100
# 45/45 - 1s - loss: 0.0032 - accuracy: 0.0015 - val_loss: 8.0133e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 539ms/epoch - 12ms/step
# Epoch 78/100
# 45/45 - 1s - loss: 0.0031 - accuracy: 0.0015 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 535ms/epoch - 12ms/step
# Epoch 79/100
# 45/45 - 1s - loss: 0.0031 - accuracy: 0.0015 - val_loss: 8.0111e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 583ms/epoch - 13ms/step
# Epoch 80/100
# 45/45 - 1s - loss: 0.0030 - accuracy: 0.0015 - val_loss: 7.1577e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 583ms/epoch - 13ms/step
# Epoch 81/100
# 45/45 - 1s - loss: 0.0030 - accuracy: 0.0015 - val_loss: 8.1942e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 592ms/epoch - 13ms/step
# Epoch 82/100
# 45/45 - 1s - loss: 0.0030 - accuracy: 0.0015 - val_loss: 8.3729e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 594ms/epoch - 13ms/step
# Epoch 83/100
# 45/45 - 1s - loss: 0.0029 - accuracy: 0.0015 - val_loss: 6.9076e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 608ms/epoch - 14ms/step
# Epoch 84/100
# 45/45 - 1s - loss: 0.0030 - accuracy: 0.0015 - val_loss: 7.0448e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 551ms/epoch - 12ms/step
# Epoch 85/100
# 45/45 - 1s - loss: 0.0030 - accuracy: 0.0015 - val_loss: 0.0014 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 532ms/epoch - 12ms/step
# Epoch 86/100
# 45/45 - 1s - loss: 0.0031 - accuracy: 0.0015 - val_loss: 6.4767e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 538ms/epoch - 12ms/step
# Epoch 87/100
# 45/45 - 1s - loss: 0.0030 - accuracy: 0.0015 - val_loss: 6.8407e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 591ms/epoch - 13ms/step
# Epoch 88/100
# 45/45 - 1s - loss: 0.0029 - accuracy: 0.0015 - val_loss: 8.3988e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 538ms/epoch - 12ms/step
# Epoch 89/100
# 45/45 - 1s - loss: 0.0029 - accuracy: 0.0015 - val_loss: 5.1229e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 540ms/epoch - 12ms/step
# Epoch 90/100
# 45/45 - 1s - loss: 0.0027 - accuracy: 0.0015 - val_loss: 8.2216e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 540ms/epoch - 12ms/step
# Epoch 91/100
# 45/45 - 1s - loss: 0.0031 - accuracy: 0.0015 - val_loss: 0.0010 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 538ms/epoch - 12ms/step
# Epoch 92/100
# 45/45 - 1s - loss: 0.0027 - accuracy: 0.0015 - val_loss: 6.4466e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 540ms/epoch - 12ms/step
# Epoch 93/100
# 45/45 - 1s - loss: 0.0025 - accuracy: 0.0015 - val_loss: 6.0636e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 583ms/epoch - 13ms/step
# Epoch 94/100
# 45/45 - 1s - loss: 0.0028 - accuracy: 0.0015 - val_loss: 9.4773e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 535ms/epoch - 12ms/step
# Epoch 95/100
# 45/45 - 1s - loss: 0.0026 - accuracy: 0.0015 - val_loss: 6.1432e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 551ms/epoch - 12ms/step
# Epoch 96/100
# 45/45 - 1s - loss: 0.0025 - accuracy: 0.0015 - val_loss: 5.2317e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 552ms/epoch - 12ms/step
# Epoch 97/100
# 45/45 - 1s - loss: 0.0024 - accuracy: 0.0015 - val_loss: 8.6117e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 600ms/epoch - 13ms/step
# Epoch 98/100
# 45/45 - 1s - loss: 0.0026 - accuracy: 0.0015 - val_loss: 7.4766e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 582ms/epoch - 13ms/step
# Epoch 99/100
# 45/45 - 1s - loss: 0.0025 - accuracy: 0.0015 - val_loss: 5.4633e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 588ms/epoch - 13ms/step
# Epoch 100/100
# 45/45 - 1s - loss: 0.0027 - accuracy: 0.0015 - val_loss: 6.8662e-04 - val_accuracy: 0.0000e+00 - lr: 0.0010 - 577ms/epoch - 13ms/step

# %%
# Plotting the training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Predicting
trainPredict = model.predict(trainX, verbose=1)
testPredict = model.predict(testX, verbose=1)

# Invert predictions
trainPredict = scaler.inverse_transform(trainPredict.reshape(trainPredict.shape[0], trainPredict.shape[1]))
trainY = scaler.inverse_transform(trainY.reshape(trainY.shape[0], trainY.shape[1]))
testPredict = scaler.inverse_transform(testPredict.reshape(testPredict.shape[0], testPredict.shape[1]))
testY = scaler.inverse_transform(testY.reshape(testY.shape[0], testY.shape[1]))

# Calculating error
trainScore = math.sqrt(mean_squared_error(trainY.flatten(), trainPredict.flatten()))
print(f'Train Score: {trainScore:.2f} RMSE')
testScore = math.sqrt(mean_squared_error(testY.flatten(), testPredict.flatten()))
print(f'Test Score: {testScore:.2f} RMSE')

trainMAE = mean_absolute_error(trainY, trainPredict)
testMAE = mean_absolute_error(testY, testPredict)
print(f'Train Score: {trainMAE:.2f} MAE')
print(f'Test Score: {testMAE:.2f} MAE')

# Plotting the predictions
plt.figure(figsize=(14, 8))

# Plotting train predictions
plt.subplot(2, 1, 1)
plt.plot(trainY[:, 0], label='Actual')
plt.plot(trainPredict[:, 0], label='Predicted')
plt.title('Training: Actual and Predicted')
plt.xlabel('Samples')
plt.ylabel('Values')
plt.legend()

# Plotting test predictions
plt.subplot(2, 1, 2)
plt.plot(testY[:, 0], label='Actual')
plt.plot(testPredict[:, 0], label='Predicted')
plt.title('Testing: Actual and Predicted')
plt.xlabel('Samples')
plt.ylabel('Values')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 23/23 [==============================] - 2s 4ms/step
# 3/3 [==============================] - 0s 5ms/step
# Train Score: 0.01 RMSE
# Test Score: 0.01 RMSE
# Train Score: 0.01 MAE
# Test Score: 0.01 MAE

# %%
# Shift train predictions for plotting
trainPredictPlot = np.empty((len(trainX) + look_back, len(time_series_dataset.columns)))
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainX) + look_back] = trainPredict

# Shift test predictions for plotting
testPredictPlot = np.empty((len(dataset_scaled), len(time_series_dataset.columns)))
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainX) + (look_back*2):len(trainX) + len(testY) + (look_back*2)] = testPredict

# Plot baseline and predictions
dset = scaler.inverse_transform(dataset_scaled)
plt.plot(dset, color="black", label='Original Data')
plt.plot(trainPredictPlot, color="blue", label='Training Result')
plt.plot(testPredictPlot, color="orange", label='Testing Result')
# Out:
# [<matplotlib.lines.Line2D at 0x2a271a64450>,
#  <matplotlib.lines.Line2D at 0x2a271a64890>,
#  <matplotlib.lines.Line2D at 0x2a271a65a10>,
#  <matplotlib.lines.Line2D at 0x2a271a55d50>,
#  <matplotlib.lines.Line2D at 0x2a271a560d0>,
#  <matplotlib.lines.Line2D at 0x2a271a66350>,
#  <matplotlib.lines.Line2D at 0x2a271a668d0>,
#  <matplotlib.lines.Line2D at 0x2a2707b6bd0>,
#  <matplotlib.lines.Line2D at 0x2a2707d1190>,
#  <matplotlib.lines.Line2D at 0x2a271a54b50>,
#  <matplotlib.lines.Line2D at 0x2a26e0f1f10>,
#  <matplotlib.lines.Line2D at 0x2a271a66e50>]

# %%
# Split the data based on mutation rate categories
high_mutation_rates = ['T->A', 'A->T']
medium_mutation_rates = ['T->C', 'C->T', 'A->C', 'C->A', 'A->G', 'G->A', 'G->T', 'T->G']
low_mutation_rates = ['G->C', 'C->G']

# Columns in the dataset
columns = ['T->C', 'T->A', 'T->G', 'C->A', 'C->G', 'A->G', 'C->T', 'A->T', 'G->T', 'A->C', 'G->C', 'G->A']

# Indices for each category
high_indices = [columns.index(col) for col in high_mutation_rates]
medium_indices = [columns.index(col) for col in medium_mutation_rates]
low_indices = [columns.index(col) for col in low_mutation_rates]

# Function to get category data
def get_category_data(data, indices):
    return data[:, indices]

# Plotting function
def plot_data(title, original_data, trainPredict, testPredict, futurePredictions, indices):
    dset = original_data[:, indices]
    trainPredictPlot = np.empty((len(trainX) + look_back, len(indices)))
    trainPredictPlot[:, :] = np.nan
    trainPredictPlot[look_back:len(trainX) + look_back] = trainPredict[:, indices]

    testPredictPlot = np.empty((len(dataset_scaled), len(indices)))
    testPredictPlot[:, :] = np.nan
    testPredictPlot[len(trainX) + (look_back * 2):len(trainX) + len(testY) + (look_back * 2)] = testPredict[:, indices]

    futurePredictPlot = np.empty((len(dset) + len(futurePredictions), len(indices)))
    futurePredictPlot[:, :] = np.nan
    futurePredictPlot[len(dset):len(dset) + len(futurePredictions)] = futurePredictions[:, indices]

    plt.figure(figsize=(14, 8))
    plt.plot(dset, color="black", label='Original Data')
    plt.plot(trainPredictPlot, color="blue", label='Training Result')
    plt.plot(testPredictPlot, color="orange", label='Testing Result')
    plt.plot(futurePredictPlot, color="red", label='Predicted Data')

    black_patch = mpatches.Patch(color='black', label='Original Data', linewidth=0)
    blue_patch = mpatches.Patch(color='blue', label='Training Result', linewidth=0)
    orange_patch = mpatches.Patch(color='orange', label='Testing Result', linewidth=0)
    red_patch = mpatches.Patch(color='red', label='Predicted Data', linewidth=0)
    plt.legend(handles=[black_patch, blue_patch, orange_patch, red_patch])

    plt.xlabel('Number of Patients')
    plt.ylabel('Mutation Rate in %')
    plt.title(title)
    plt.grid(True)
    plt.show()

# Inverse transform the entire dataset
original_data = scaler.inverse_transform(dataset_scaled)

# Generate future predictions
futureData = [testX[-1]]
futurePredictions = []

for i in range(60):  # Predict next 60 steps
    futurePredict = model.predict(np.array(futureData[-1]).reshape(1, look_back, len(time_series_dataset.columns)))
    futurePredictions.append(futurePredict)
    futureData.append(np.roll(futureData[-1], -1, axis=0))
    futureData[-1][-1] = futurePredict.reshape(-1)

futurePredictions = np.array(futurePredictions).reshape(-1, len(time_series_dataset.columns))
futurePredictions = scaler.inverse_transform(futurePredictions)

# Plotting for each category
for title, indices in zip(
    ["High Mutation Rates", "Medium Mutation Rates", "Low Mutation Rates"],
    [high_indices, medium_indices, low_indices]
):
    plot_data(title, original_data, trainPredict, testPredict, futurePredictions, indices)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
