# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
import matplotlib.patches as mpatches
# Out:
# WARNING:tensorflow:From C:\Users\alek7andra13\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load the dataset from CSV
time_series_dataset = pd.read_csv('../outputs/mutation_timeseries3.csv', skiprows=1)

# Convert the dataset to float32
time_series_dataset = time_series_dataset.astype('float32')
print('Dataset Shape: ', time_series_dataset.shape)

# Apply Min-Max scaling
scaler = MinMaxScaler(feature_range=(0, 1))
dataset_scaled = scaler.fit_transform(time_series_dataset)

# Split dataset into train and test sets
train_size = int(len(dataset_scaled) * 0.90)
train, test = dataset_scaled[:train_size], dataset_scaled[train_size:]
print(len(train), len(test))
# Out:
# Dataset Shape:  (806, 12)
# 725 81

# %%
def create_dataset(time_series_dataset, look_back, batch_size):
    dataX, dataY = [], []
    for i in range(0, len(time_series_dataset) - look_back - 1, batch_size):
        a = time_series_dataset[i:(i + look_back)]
        dataX.append(a)
        dataY.append(time_series_dataset[i + look_back])
    return np.array(dataX), np.array(dataY)

batch_size = 1
look_back = 12
trainX, trainY = create_dataset(train, look_back, batch_size)
testX, testY = create_dataset(test, look_back, batch_size)
print(len(trainX), len(testX))
# Out:
# 712 68

# %%
# Build and Train LSTM Network
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(look_back, len(time_series_dataset.columns))))
model.add(Dropout(0.2))
model.add(LSTM(50))
model.add(Dropout(0.2))
model.add(Dense(len(time_series_dataset.columns)))
model.compile(loss='mean_squared_error', optimizer='adam')

# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, min_lr=0.001)

history = model.fit(trainX, trainY, epochs=100, batch_size=16, verbose=2, validation_data=(testX, testY), callbacks=[early_stop, reduce_lr])
# Out:
# WARNING:tensorflow:From C:\Users\alek7andra13\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\alek7andra13\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\alek7andra13\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 45/45 - 6s - loss: 0.0328 - val_loss: 9.6083e-04 - lr: 0.0010 - 6s/epoch - 139ms/step
# Epoch 2/100
# 45/45 - 0s - loss: 0.0107 - val_loss: 4.0995e-04 - lr: 0.0010 - 442ms/epoch - 10ms/step
# Epoch 3/100
# 45/45 - 0s - loss: 0.0095 - val_loss: 1.9421e-04 - lr: 0.0010 - 432ms/epoch - 10ms/step
# Epoch 4/100
# 45/45 - 0s - loss: 0.0076 - val_loss: 4.9628e-04 - lr: 0.0010 - 416ms/epoch - 9ms/step
# Epoch 5/100
# 45/45 - 0s - loss: 0.0071 - val_loss: 4.6046e-04 - lr: 0.0010 - 414ms/epoch - 9ms/step
# Epoch 6/100
# 45/45 - 0s - loss: 0.0066 - val_loss: 3.0736e-04 - lr: 0.0010 - 428ms/epoch - 10ms/step
# Epoch 7/100
# 45/45 - 0s - loss: 0.0067 - val_loss: 4.6234e-04 - lr: 0.0010 - 416ms/epoch - 9ms/step
# Epoch 8/100
# 45/45 - 0s - loss: 0.0064 - val_loss: 3.3213e-04 - lr: 0.0010 - 436ms/epoch - 10ms/step
# Epoch 9/100
# 45/45 - 0s - loss: 0.0059 - val_loss: 4.1455e-04 - lr: 0.0010 - 462ms/epoch - 10ms/step
# Epoch 10/100
# 45/45 - 0s - loss: 0.0052 - val_loss: 1.8853e-04 - lr: 0.0010 - 469ms/epoch - 10ms/step
# Epoch 11/100
# 45/45 - 0s - loss: 0.0045 - val_loss: 2.3079e-04 - lr: 0.0010 - 427ms/epoch - 9ms/step
# Epoch 12/100
# 45/45 - 0s - loss: 0.0044 - val_loss: 2.5465e-04 - lr: 0.0010 - 447ms/epoch - 10ms/step
# Epoch 13/100
# 45/45 - 0s - loss: 0.0043 - val_loss: 2.3839e-04 - lr: 0.0010 - 432ms/epoch - 10ms/step
# Epoch 14/100
# 45/45 - 0s - loss: 0.0041 - val_loss: 9.0307e-04 - lr: 0.0010 - 468ms/epoch - 10ms/step
# Epoch 15/100
# 45/45 - 0s - loss: 0.0045 - val_loss: 1.5704e-04 - lr: 0.0010 - 436ms/epoch - 10ms/step
# Epoch 16/100
# 45/45 - 0s - loss: 0.0040 - val_loss: 3.8924e-04 - lr: 0.0010 - 458ms/epoch - 10ms/step
# Epoch 17/100
# 45/45 - 0s - loss: 0.0038 - val_loss: 2.8772e-04 - lr: 0.0010 - 438ms/epoch - 10ms/step
# Epoch 18/100
# 45/45 - 0s - loss: 0.0038 - val_loss: 4.2482e-04 - lr: 0.0010 - 413ms/epoch - 9ms/step
# Epoch 19/100
# 45/45 - 0s - loss: 0.0032 - val_loss: 5.2302e-04 - lr: 0.0010 - 464ms/epoch - 10ms/step
# Epoch 20/100
# 45/45 - 0s - loss: 0.0032 - val_loss: 4.0486e-04 - lr: 0.0010 - 424ms/epoch - 9ms/step
# Epoch 21/100
# 45/45 - 0s - loss: 0.0032 - val_loss: 2.0178e-04 - lr: 0.0010 - 484ms/epoch - 11ms/step
# Epoch 22/100
# 45/45 - 0s - loss: 0.0041 - val_loss: 3.8040e-04 - lr: 0.0010 - 425ms/epoch - 9ms/step
# Epoch 23/100
# 45/45 - 0s - loss: 0.0026 - val_loss: 1.5918e-04 - lr: 0.0010 - 407ms/epoch - 9ms/step
# Epoch 24/100
# 45/45 - 0s - loss: 0.0029 - val_loss: 2.2444e-04 - lr: 0.0010 - 414ms/epoch - 9ms/step
# Epoch 25/100
# 45/45 - 0s - loss: 0.0031 - val_loss: 2.3462e-04 - lr: 0.0010 - 444ms/epoch - 10ms/step
# Epoch 26/100
# 45/45 - 0s - loss: 0.0028 - val_loss: 3.0499e-04 - lr: 0.0010 - 496ms/epoch - 11ms/step
# Epoch 27/100
# 45/45 - 0s - loss: 0.0033 - val_loss: 1.9805e-04 - lr: 0.0010 - 467ms/epoch - 10ms/step
# Epoch 28/100
# 45/45 - 0s - loss: 0.0030 - val_loss: 2.2546e-04 - lr: 0.0010 - 481ms/epoch - 11ms/step
# Epoch 29/100
# 45/45 - 0s - loss: 0.0026 - val_loss: 1.2693e-04 - lr: 0.0010 - 493ms/epoch - 11ms/step
# Epoch 30/100
# 45/45 - 0s - loss: 0.0025 - val_loss: 2.9165e-04 - lr: 0.0010 - 428ms/epoch - 10ms/step
# Epoch 31/100
# 45/45 - 1s - loss: 0.0022 - val_loss: 2.5470e-04 - lr: 0.0010 - 582ms/epoch - 13ms/step
# Epoch 32/100
# 45/45 - 0s - loss: 0.0026 - val_loss: 4.3841e-04 - lr: 0.0010 - 461ms/epoch - 10ms/step
# Epoch 33/100
# 45/45 - 0s - loss: 0.0026 - val_loss: 3.1874e-04 - lr: 0.0010 - 448ms/epoch - 10ms/step
# Epoch 34/100
# 45/45 - 0s - loss: 0.0024 - val_loss: 2.0119e-04 - lr: 0.0010 - 479ms/epoch - 11ms/step
# Epoch 35/100
# 45/45 - 0s - loss: 0.0026 - val_loss: 1.8374e-04 - lr: 0.0010 - 448ms/epoch - 10ms/step
# Epoch 36/100
# 45/45 - 0s - loss: 0.0021 - val_loss: 1.3072e-04 - lr: 0.0010 - 439ms/epoch - 10ms/step
# Epoch 37/100
# 45/45 - 0s - loss: 0.0026 - val_loss: 1.2972e-04 - lr: 0.0010 - 455ms/epoch - 10ms/step
# Epoch 38/100
# 45/45 - 0s - loss: 0.0019 - val_loss: 1.4700e-04 - lr: 0.0010 - 432ms/epoch - 10ms/step
# Epoch 39/100
# 45/45 - 0s - loss: 0.0023 - val_loss: 1.5582e-04 - lr: 0.0010 - 463ms/epoch - 10ms/step
# Epoch 40/100
# 45/45 - 0s - loss: 0.0019 - val_loss: 1.5194e-04 - lr: 0.0010 - 490ms/epoch - 11ms/step
# Epoch 41/100
# 45/45 - 1s - loss: 0.0020 - val_loss: 2.4259e-04 - lr: 0.0010 - 528ms/epoch - 12ms/step
# Epoch 42/100
# 45/45 - 0s - loss: 0.0019 - val_loss: 1.2217e-04 - lr: 0.0010 - 449ms/epoch - 10ms/step
# Epoch 43/100
# 45/45 - 0s - loss: 0.0021 - val_loss: 1.1776e-04 - lr: 0.0010 - 434ms/epoch - 10ms/step
# Epoch 44/100
# 45/45 - 1s - loss: 0.0019 - val_loss: 1.5296e-04 - lr: 0.0010 - 552ms/epoch - 12ms/step
# Epoch 45/100
# 45/45 - 0s - loss: 0.0020 - val_loss: 1.7736e-04 - lr: 0.0010 - 488ms/epoch - 11ms/step
# Epoch 46/100
# 45/45 - 0s - loss: 0.0021 - val_loss: 2.8770e-04 - lr: 0.0010 - 461ms/epoch - 10ms/step
# Epoch 47/100
# 45/45 - 0s - loss: 0.0022 - val_loss: 1.9656e-04 - lr: 0.0010 - 446ms/epoch - 10ms/step
# Epoch 48/100
# 45/45 - 0s - loss: 0.0023 - val_loss: 2.0344e-04 - lr: 0.0010 - 481ms/epoch - 11ms/step
# Epoch 49/100
# 45/45 - 0s - loss: 0.0019 - val_loss: 1.5105e-04 - lr: 0.0010 - 459ms/epoch - 10ms/step
# Epoch 50/100
# 45/45 - 0s - loss: 0.0021 - val_loss: 1.6314e-04 - lr: 0.0010 - 484ms/epoch - 11ms/step
# Epoch 51/100
# 45/45 - 0s - loss: 0.0016 - val_loss: 2.0901e-04 - lr: 0.0010 - 421ms/epoch - 9ms/step
# Epoch 52/100
# 45/45 - 0s - loss: 0.0024 - val_loss: 1.8100e-04 - lr: 0.0010 - 417ms/epoch - 9ms/step
# Epoch 53/100
# 45/45 - 1s - loss: 0.0021 - val_loss: 1.7960e-04 - lr: 0.0010 - 504ms/epoch - 11ms/step
# Epoch 54/100
# 45/45 - 0s - loss: 0.0019 - val_loss: 4.2780e-04 - lr: 0.0010 - 432ms/epoch - 10ms/step
# Epoch 55/100
# 45/45 - 0s - loss: 0.0018 - val_loss: 1.0728e-04 - lr: 0.0010 - 429ms/epoch - 10ms/step
# Epoch 56/100
# 45/45 - 0s - loss: 0.0021 - val_loss: 2.6897e-04 - lr: 0.0010 - 414ms/epoch - 9ms/step
# Epoch 57/100
# 45/45 - 0s - loss: 0.0018 - val_loss: 1.3724e-04 - lr: 0.0010 - 423ms/epoch - 9ms/step
# Epoch 58/100
# 45/45 - 0s - loss: 0.0017 - val_loss: 2.4102e-04 - lr: 0.0010 - 428ms/epoch - 10ms/step
# Epoch 59/100
# 45/45 - 0s - loss: 0.0019 - val_loss: 1.5128e-04 - lr: 0.0010 - 429ms/epoch - 10ms/step
# Epoch 60/100
# 45/45 - 0s - loss: 0.0018 - val_loss: 3.1623e-04 - lr: 0.0010 - 423ms/epoch - 9ms/step
# Epoch 61/100
# 45/45 - 0s - loss: 0.0021 - val_loss: 1.7272e-04 - lr: 0.0010 - 418ms/epoch - 9ms/step
# Epoch 62/100
# 45/45 - 0s - loss: 0.0019 - val_loss: 3.9432e-04 - lr: 0.0010 - 398ms/epoch - 9ms/step
# Epoch 63/100
# 45/45 - 0s - loss: 0.0021 - val_loss: 1.5042e-04 - lr: 0.0010 - 414ms/epoch - 9ms/step
# Epoch 64/100
# 45/45 - 0s - loss: 0.0016 - val_loss: 1.8109e-04 - lr: 0.0010 - 431ms/epoch - 10ms/step
# Epoch 65/100
# 45/45 - 0s - loss: 0.0018 - val_loss: 1.3045e-04 - lr: 0.0010 - 407ms/epoch - 9ms/step
# Epoch 66/100
# 45/45 - 0s - loss: 0.0018 - val_loss: 1.7089e-04 - lr: 0.0010 - 407ms/epoch - 9ms/step
# Epoch 67/100
# 45/45 - 0s - loss: 0.0018 - val_loss: 2.8215e-04 - lr: 0.0010 - 475ms/epoch - 11ms/step
# Epoch 68/100
# 45/45 - 0s - loss: 0.0019 - val_loss: 1.3563e-04 - lr: 0.0010 - 426ms/epoch - 9ms/step
# Epoch 69/100
# 45/45 - 0s - loss: 0.0020 - val_loss: 4.0370e-04 - lr: 0.0010 - 413ms/epoch - 9ms/step
# Epoch 70/100
# 45/45 - 0s - loss: 0.0018 - val_loss: 2.8599e-04 - lr: 0.0010 - 409ms/epoch - 9ms/step
# Epoch 71/100
# 45/45 - 0s - loss: 0.0018 - val_loss: 1.7244e-04 - lr: 0.0010 - 487ms/epoch - 11ms/step
# Epoch 72/100
# 45/45 - 0s - loss: 0.0016 - val_loss: 2.0817e-04 - lr: 0.0010 - 446ms/epoch - 10ms/step
# Epoch 73/100
# 45/45 - 0s - loss: 0.0017 - val_loss: 2.9196e-04 - lr: 0.0010 - 470ms/epoch - 10ms/step
# Epoch 74/100
# 45/45 - 0s - loss: 0.0016 - val_loss: 1.8045e-04 - lr: 0.0010 - 438ms/epoch - 10ms/step
# Epoch 75/100
# 45/45 - 0s - loss: 0.0019 - val_loss: 3.8923e-04 - lr: 0.0010 - 472ms/epoch - 10ms/step

# %%
# Plotting the training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Predicting
trainPredict = model.predict(trainX, verbose=1)
testPredict = model.predict(testX, verbose=1)

# Invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform(trainY)
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform(testY)

# Calculating error
trainScore = math.sqrt(mean_squared_error(trainY, trainPredict))
print(f'Train Score: {trainScore:.2f} RMSE')
testScore = math.sqrt(mean_squared_error(testY, testPredict))
print(f'Test Score: {testScore:.2f} RMSE')

trainMAE = mean_absolute_error(trainY, trainPredict)
testMAE = mean_absolute_error(testY, testPredict)
print(f'Train Score: {trainMAE:.2f} MAE')
print(f'Test Score: {testMAE:.2f} MAE')

# Plotting the predictions
plt.figure(figsize=(14, 8))

# Plotting train predictions
plt.subplot(2, 1, 1)
plt.plot(trainY[:, 0], label='Actual')
plt.plot(trainPredict[:, 0], label='Predicted')
plt.title('Training: Actual and Predicted')
plt.xlabel('Samples')
plt.ylabel('Values')
plt.legend()

# Plotting test predictions
plt.subplot(2, 1, 2)
plt.plot(testY[:, 0], label='Actual')
plt.plot(testPredict[:, 0], label='Predicted')
plt.title('Testing: Actual and Predicted')
plt.xlabel('Samples')
plt.ylabel('Values')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 23/23 [==============================] - 1s 4ms/step
# 3/3 [==============================] - 0s 4ms/step
# Train Score: 0.01 RMSE
# Test Score: 0.00 RMSE
# Train Score: 0.00 MAE
# Test Score: 0.00 MAE

# %%
# Split the data based on mutation rate categories
high_mutation_rates = ['T->A', 'A->T']
medium_mutation_rates = ['T->C', 'C->T', 'A->C', 'C->A', 'A->G', 'G->A', 'G->T', 'T->G']
low_mutation_rates = ['G->C', 'C->G']

# Columns in the dataset
columns = ['T->C', 'T->A', 'T->G', 'C->A', 'C->G', 'A->G', 'C->T', 'A->T', 'G->T', 'A->C', 'G->C', 'G->A']

# Indices for each category
high_indices = [columns.index(col) for col in high_mutation_rates]
medium_indices = [columns.index(col) for col in medium_mutation_rates]
low_indices = [columns.index(col) for col in low_mutation_rates]

# Function to get category data
def get_category_data(data, indices):
    return data[:, indices]

# Plotting function
def plot_data(title, original_data, trainPredict, testPredict, futurePredictions, indices):
    dset = original_data[:, indices]
    trainPredictPlot = np.empty((len(trainX) + look_back, len(indices)))
    trainPredictPlot[:, :] = np.nan
    trainPredictPlot[look_back:len(trainX) + look_back] = trainPredict[:, indices]

    testPredictPlot = np.empty((len(dataset_scaled), len(indices)))
    testPredictPlot[:, :] = np.nan
    testPredictPlot[len(trainX) + (look_back * 2):len(trainX) + len(testY) + (look_back * 2)] = testPredict[:, indices]

    futurePredictPlot = np.empty((len(dset) + len(futurePredictions), len(indices)))
    futurePredictPlot[:, :] = np.nan
    futurePredictPlot[len(dset):len(dset) + len(futurePredictions)] = futurePredictions[:, indices]

    plt.figure(figsize=(14, 8))
    plt.plot(dset, color="black", label='Original Data')
    plt.plot(trainPredictPlot, color="blue", label='Training Result')
    plt.plot(testPredictPlot, color="orange", label='Testing Result')
    plt.plot(futurePredictPlot, color="red", label='Predicted Data')

    black_patch = mpatches.Patch(color='black', label='Original Data', linewidth=0)
    blue_patch = mpatches.Patch(color='blue', label='Training Result', linewidth=0)
    orange_patch = mpatches.Patch(color='orange', label='Testing Result', linewidth=0)
    red_patch = mpatches.Patch(color='red', label='Predicted Data', linewidth=0)
    plt.legend(handles=[black_patch, blue_patch, orange_patch, red_patch])

    plt.xlabel('Number of Patients')
    plt.ylabel('Mutation Rate in %')
    plt.title(title)
    plt.grid(True)
    plt.show()

# Inverse transform the entire dataset
original_data = scaler.inverse_transform(dataset_scaled)

# Generate future predictions
futureData = [testX[-1]]
futurePredictions = []

for i in range(60):  # Predict next 60 steps
    futurePredict = model.predict(np.array(futureData[-1]).reshape(1, look_back, len(time_series_dataset.columns)))
    futurePredictions.append(futurePredict)
    futureData.append(np.roll(futureData[-1], -1, axis=0))
    futureData[-1][-1] = futurePredict

futurePredictions = np.array(futurePredictions).reshape(-1, len(time_series_dataset.columns))
futurePredictions = scaler.inverse_transform(futurePredictions)

# Plotting for each category
for title, indices in zip(
    ["High Mutation Rates", "Medium Mutation Rates", "Low Mutation Rates"],
    [high_indices, medium_indices, low_indices]
):
    plot_data(title, original_data, trainPredict, testPredict, futurePredictions, indices)
# Out:
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
